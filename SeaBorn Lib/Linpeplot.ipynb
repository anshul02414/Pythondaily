# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
data = {"Days":[1,2,3,4,5,6,7],
        "NOP":[20,22,14,51,44,35,62]}

df = pd.DataFrame(data)
df
# Out:
#    Days  NOP
# 0     1   20
# 1     2   22
# 2     3   14
# 3     4   51
# 4     5   44
# 5     6   35
# 6     7   62

# %%
sns.lineplot(data=data, x="Days", y="NOP")
plt.show()

# %%
data = pd.read_excel("ESD.xlsx")
df = pd.DataFrame(data)
df.head(5)
# Out:
#      EEID        Full Name                 Job Title Department  \
# 0  E02387      Emily Davis                Sr. Manger         IT
# 1  E04105    Theodore Dinh       Technical Architect         IT
# 2  E02572     Luna Sanders                  Director    Finance
# 3  E02832  Penelope Jordan  Computer Systems Manager         IT
# 4  E01639        Austin Vo               Sr. Analyst    Finance
#
#             Business Unit  Gender  Ethnicity  Age  Hire Date  Annual Salary  \
# 0  Research & Development  Female      Black   55 2016-04-08         141604
# 1           Manufacturing    Male      Asian   59 1997-11-29          99975
# 2     Speciality Products  Female  Caucasian   50 2006-10-26         163099
# 3           Manufacturing  Female  Caucasian   26 2019-09-27          84913
# 4           Manufacturing    Male      Asian   55 1995-11-20          95409
#
#    Bonus %        Country       City  Exit Date
# 0     0.15  United States    Seattle 2021-10-16
# ...

# %% [markdown]
# department age
#
# department Selary

# %%
grp = df.groupby("Department")["Age"].sum()

# %%
grp
# Out:
# Department
# Accounting          4191
# Engineering         7216
# Finance             5435
# Human Resources     5557
# IT                 10687
# Marketing           5186
# Sales               6110
# Name: Age, dtype: int64

# %%
grp.index
# Out:
# Index(['Accounting', 'Engineering', 'Finance', 'Human Resources', 'IT',
#        'Marketing', 'Sales'],
#       dtype='object', name='Department')

# %%
grp.values
# Out:
# array([ 4191,  7216,  5435,  5557, 10687,  5186,  6110])

# %%
df["Department"].unique()
# Out:
# array(['IT', 'Finance', 'Sales', 'Accounting', 'Human Resources',
#        'Engineering', 'Marketing'], dtype=object)

# %%
sns.lineplot(x=grp.index, y=grp.values)
plt.xticks(rotation=45, ha="right")
plt.show()

# %%
df.head
# Out:
# <bound method NDFrame.head of        EEID        Full Name                 Job Title  Department  \
# 0    E02387      Emily Davis                Sr. Manger          IT
# 1    E04105    Theodore Dinh       Technical Architect          IT
# 2    E02572     Luna Sanders                  Director     Finance
# 3    E02832  Penelope Jordan  Computer Systems Manager          IT
# 4    E01639        Austin Vo               Sr. Analyst     Finance
# ..      ...              ...                       ...         ...
# 995  E03094     Wesley Young               Sr. Analyst   Marketing
# 996  E01909     Lillian Khan                   Analyst     Finance
# 997  E04398      Oliver Yang                  Director   Marketing
# 998  E02521      Lily Nguyen               Sr. Analyst     Finance
# 999  E03545      Sofia Cheng            Vice President  Accounting
#
#               Business Unit  Gender  Ethnicity  Age  Hire Date  Annual Salary  \
# ...

# %%
sns.lineplot(data=data, x="Department", y="Age")
# Out:
# <Axes: xlabel='Department', ylabel='Age'>

# %%
sns.lineplot(data=data, x="Department", y="Age", hue="Gender", )
# Out:
# <Axes: xlabel='Department', ylabel='Age'>
