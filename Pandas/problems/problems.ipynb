# %%
import pandas as pd

# %%
"""
Ye dictionary di hui hai:
data = {
    "Name": ["Amit", "Priya", "Rahul"],
    "Age": [25, 28, 30],
    "Salary": [50000, 60000, 70000]
}
"""
data = {
    "Name": ["Amit", "Priya", "Rahul"],
    "Age": [25, 28, 30],
    "Salary": [50000, 60000, 70000]
}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#     Name  Age  Salary
# 0   Amit   25   50000
# 1  Priya   28   60000
# 2  Rahul   30   70000

# %%
"""2. Display Information
Upar wale DataFrame ke liye:
First 2 rows
Last row
Column names
Shape
nikalo."""
# Out:
# '2. Display Information\nUpar wale DataFrame ke liye:\nFirst 2 rows\nLast row\nColumn names\nShape\nnikalo.'

# %%
df.head(2)
# Out:
#     Name  Age  Salary
# 0   Amit   25   50000
# 1  Priya   28   60000

# %%
df.tail(1)
# Out:
#     Name  Age  Salary
# 2  Rahul   30   70000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    3 non-null      object
#  1   Age     3 non-null      int64
#  2   Salary  3 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 200.0+ bytes

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'Salary'], dtype='object')

# %%
df.shape
# Out:
# (3, 3)

# %%
"""3. Select Columns
Print:
Name
Salary
columns."""
# Out:
# '3. Select Columns\nPrint:\nName\nSalary\ncolumns.'

# %%
df["Name"]
# Out:
# 0     Amit
# 1    Priya
# 2    Rahul
# Name: Name, dtype: object

# %%
df["Salary"]
# Out:
# 0    50000
# 1    60000
# 2    70000
# Name: Salary, dtype: int64

# %%
""" 
4. Select Single Row
Rahul wali row nikalo using:
loc
iloc
"""
# Out:
# ' \n4. Select Single Row\nRahul wali row nikalo using:\nloc\niloc\n'

# %%
print(df.loc[0])
# Out:
# Name       Amit
# Age          25
# Salary    50000
# Name: 0, dtype: object

# %%
data = df[df["Name"] == "Rahul"].index[0]

# %%
df.loc[data]
# Out:
# Name      Rahul
# Age          30
# Salary    70000
# Name: 2, dtype: object

# %%
df.iloc[data]
# Out:
# Name      Rahul
# Age          30
# Salary    70000
# Name: 2, dtype: object

# %%
""" 
5. Add New Column
Ek new column banao:
Bonus = Salary * 0.10
"""
# Out:
# ' \n5. Add New Column\nEk new column banao:\nBonus = Salary * 0.10\n'

# %%
df
# Out:
#     Name  Age  Salary
# 0   Amit   25   50000
# 1  Priya   28   60000
# 2  Rahul   30   70000

# %%
df["Bonas"] = df["Salary"] * 0.10

# %%
df
# Out:
#     Name  Age  Salary   Bonas
# 0   Amit   25   50000  5000.0
# 1  Priya   28   60000  6000.0
# 2  Rahul   30   70000  7000.0

# %%
""" 
6. Rename Column
Salary
ko
Monthly_Salary
rename karo.
"""
# Out:
# ' \n6. Rename Column\nSalary\nko\nMonthly_Salary\nrename karo.\n'

# %%
df.rename(columns={"Salary": "Monthly_Salary"}, inplace=True)

# %%
df
# Out:
#     Name  Age  Monthly_Salary   Bonas
# 0   Amit   25           50000  5000.0
# 1  Priya   28           60000  6000.0
# 2  Rahul   30           70000  7000.0

# %%
""" 
7. Delete Column
Bonus column hatao.
"""
# Out:
# ' \n7. Delete Column\nBonus column hatao.\n'

# %%
del df["Bonas"]

# %%
df
# Out:
#     Name  Age  Monthly_Salary
# 0   Amit   25           50000
# 1  Priya   28           60000
# 2  Rahul   30           70000

# %%
# df.drop(
#         columns=["Bonas"],
#         inplace=True
# )

# %%
""" 
8. Salary Greater Than 60000
Sirf un employees ko dikhao jinki salary 60000 se zyada hai.
"""
# Out:
# ' \n8. Salary Greater Than 60000\nSirf un employees ko dikhao jinki salary 60000 se zyada hai.\n'

# %%
df
# Out:
#     Name  Age  Monthly_Salary
# 0   Amit   25           50000
# 1  Priya   28           60000
# 2  Rahul   30           70000

# %%
df[df["Monthly_Salary"] > 60000]
# Out:
#     Name  Age  Monthly_Salary
# 2  Rahul   30           70000

# %%
df[(df["Monthly_Salary"] > 60000) & (df["Age"] > 25)]
# Out:
#     Name  Age  Monthly_Salary
# 2  Rahul   30           70000

# %%
""" 
10. String Filtering
Sirf un logon ko dikhao jinke naam me letter:
"a"

aata ho.
"""
# Out:
# ' \n10. String Filtering\nSirf un logon ko dikhao jinke naam me letter:\n"a"\n\naata ho.\n'
