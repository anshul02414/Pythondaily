# %%
import pandas as pd

# %%
data = pd.read_excel("ESD.xlsx")

# %%
data
# Out:
#        EEID        Full Name                 Job Title  Department  \
# 0    E02387      Emily Davis                Sr. Manger          IT
# 1    E04105    Theodore Dinh       Technical Architect          IT
# 2    E02572     Luna Sanders                  Director     Finance
# 3    E02832  Penelope Jordan  Computer Systems Manager          IT
# 4    E01639        Austin Vo               Sr. Analyst     Finance
# ..      ...              ...                       ...         ...
# 995  E03094     Wesley Young               Sr. Analyst   Marketing
# 996  E01909     Lillian Khan                   Analyst     Finance
# 997  E04398      Oliver Yang                  Director   Marketing
# 998  E02521      Lily Nguyen               Sr. Analyst     Finance
# 999  E03545      Sofia Cheng            Vice President  Accounting
#
#               Business Unit  Gender  Ethnicity  Age  Hire Date  Annual Salary  \
# 0    Research & Development  Female      Black   55 2016-04-08         141604
# ...

# %%
grp = data.groupby("Department").agg({"Gender":"count"})

# %%
print(grp)
# Out:
#                  Gender
# Department
# Accounting           96
# Engineering         158
# Finance             120
# Human Resources     125
# IT                  241
# Marketing           120
# Sales               140

# %%
grp = data.groupby(["Department", "Gender"]).agg({"Gender":"count"})

# %%
grp
# Out:
#                         Gender
# Department      Gender
# Accounting      Female      53
#                 Male        43
# Engineering     Female      80
#                 Male        78
# Finance         Female      69
#                 Male        51
# Human Resources Female      64
#                 Male        61
# IT              Female     119
#                 Male       122
# Marketing       Female      57
#                 Male        63
# Sales           Female      76
#                 Male        64

# %%
grp = data.groupby("Country").agg({"Annual Salary":"max"})

# %%
grp
# Out:
#                Annual Salary
# Country
# Brazil                258426
# China                 257194
# United States         258498

# %%
data.head(5)
# Out:
#      EEID        Full Name                 Job Title Department  \
# 0  E02387      Emily Davis                Sr. Manger         IT
# 1  E04105    Theodore Dinh       Technical Architect         IT
# 2  E02572     Luna Sanders                  Director    Finance
# 3  E02832  Penelope Jordan  Computer Systems Manager         IT
# 4  E01639        Austin Vo               Sr. Analyst    Finance
#
#             Business Unit  Gender  Ethnicity  Age  Hire Date  Annual Salary  \
# 0  Research & Development  Female      Black   55 2016-04-08         141604
# 1           Manufacturing    Male      Asian   59 1997-11-29          99975
# 2     Speciality Products  Female  Caucasian   50 2006-10-26         163099
# 3           Manufacturing  Female  Caucasian   26 2019-09-27          84913
# 4           Manufacturing    Male      Asian   55 1995-11-20          95409
#
#    Bonus %        Country       City  Exit Date
# 0     0.15  United States    Seattle 2021-10-16
# ...

# %%
data.groupby("Department")["Annual Salary"].sum()
# Out:
# Department
# Accounting         11822107
# Engineering        17227563
# Finance            14736347
# Human Resources    14757305
# IT                 23567499
# Marketing          15559564
# Sales              15546980
# Name: Annual Salary, dtype: int64

# %%
data.groupby(["Department", "Gender"])["Annual Salary"].sum()
# Out:
# Department       Gender
# Accounting       Female     6914128
#                  Male       4907979
# Engineering      Female     8377656
#                  Male       8849907
# Finance          Female     8424540
#                  Male       6311807
# Human Resources  Female     7693326
#                  Male       7063979
# IT               Female    11344574
#                  Male      12222925
# Marketing        Female     7145899
#                  Male       8413665
# Sales            Female     8278622
#                  Male       7268358
# Name: Annual Salary, dtype: int64

# %%
data.groupby(["Department", "Gender"])["Annual Salary"].count()
# Out:
# Department       Gender
# Accounting       Female     53
#                  Male       43
# Engineering      Female     80
#                  Male       78
# Finance          Female     69
#                  Male       51
# Human Resources  Female     64
#                  Male       61
# IT               Female    119
#                  Male      122
# Marketing        Female     57
#                  Male       63
# Sales            Female     76
#                  Male       64
# Name: Annual Salary, dtype: int64

# %%
data.groupby(["Department", "Gender"])["Annual Salary"].agg(["min", "max"])
# Out:
#                           min     max
# Department      Gender
# Accounting      Female  45049  258426
#                 Male    50883  252325
# Engineering     Female  60017  255431
#                 Male    60055  254289
# Finance         Female  43363  255369
#                 Male    41336  250767
# Human Resources Female  43001  249801
#                 Male    41728  250953
# IT              Female  40124  246589
#                 Male    40063  256561
# Marketing       Female  40897  249270
#                 Male    40752  257194
# Sales           Female  41429  258498
#                 Male    44732  258081
