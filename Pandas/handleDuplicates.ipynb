# %%
import pandas as pd

data = pd.read_csv("data.csv")

# %%
data
# Out:
#     EEID    Name  Gander  Salary
# 0    101    Amit    Male   45000
# 1    102    Neha  Female   52000
# 2    103   Rahul    Male   48000
# 3    104   Priya  Female   55000
# 4    105  Suresh    Male   60000
# 5    106  Kavita  Female   47000
# 6    107   Vikas    Male   51000
# 7    108   Pooja  Female   53000
# 8    109   Rohan    Male   49000
# 9    110  Anjali  Female   56000
# 10   103   Rahul    Male   48000
# 11   105  Suresh    Male   60000
# 12   108   Pooja  Female   53000
# 13   111  Deepak    Male   62000
# 14   112  Shreya  Female   58000

# %%
print(data["EEID"].duplicated())
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10     True
# 11     True
# 12     True
# 13    False
# 14    False
# Name: EEID, dtype: bool

# %%
print(data["EEID"].duplicated().sum())
# Out:
# 3

# %%
print(data.drop_duplicates("EEID"))
# Out:
#     EEID    Name  Gander  Salary
# 0    101    Amit    Male   45000
# 1    102    Neha  Female   52000
# 2    103   Rahul    Male   48000
# 3    104   Priya  Female   55000
# 4    105  Suresh    Male   60000
# 5    106  Kavita  Female   47000
# 6    107   Vikas    Male   51000
# 7    108   Pooja  Female   53000
# 8    109   Rohan    Male   49000
# 9    110  Anjali  Female   56000
# 13   111  Deepak    Male   62000
# 14   112  Shreya  Female   58000

# %%
print(data.shape)
# Out:
# (15, 4)
