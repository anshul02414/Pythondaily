# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
day = ["d1", "d2", "d3", "d4", "d5", "d6", "d7"]
y = [22,34,54,32,65,64,10]

plt.step(day, y, color="black")
plt.show()

# %%
data = pd.read_excel("expense3.xlsx")

df = pd.DataFrame(data)
df.head(5)
# Out:
#         Date    Category Sub-Category   Amount Payment Mode
# 0 2023-01-01     Grocery       Grocery      30         Cash
# 1 2023-01-02        Food    Restaurant     890          UPI
# 2 2023-01-04         123        Zomato     257          NaN
# 3 2023-01-06  Essentials         Diary     120          UPI
# 4 2023-01-06  Essentials       Perfume    1500         Cash

# %%
grp = df.groupby("Category")["Amount"].sum()

# %%
grp
# Out:
# Category
# 123             257
# Bills         18724
# Clothes        2890
# Essentials     4485
# Food           2765
# Grocery        1028
# Name: Amount, dtype: int64

# %%
x = range(len(grp))
plt.step(x, grp.values)
plt.xticks(x, grp.index, rotation=45)
plt.show()
