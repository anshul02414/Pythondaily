# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import random

# %%
x = np.random.randint(1,500,100)
plt.violinplot(x, showmedians=True)
# Out:
# {'bodies': [<matplotlib.collections.FillBetweenPolyCollection at 0x20409f759c0>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x20409f75f60>,
#  'cmins': <matplotlib.collections.LineCollection at 0x20409f76500>,
#  'cbars': <matplotlib.collections.LineCollection at 0x20409f76b60>,
#  'cmedians': <matplotlib.collections.LineCollection at 0x20409f771c0>}

# %%
data = pd.read_excel("expense3.xlsx")
df = pd.DataFrame(data)

df.head(5)
# Out:
#         Date    Category Sub-Category   Amount Payment Mode
# 0 2023-01-01     Grocery       Grocery      30         Cash
# 1 2023-01-02        Food    Restaurant     890          UPI
# 2 2023-01-04         123        Zomato     257          NaN
# 3 2023-01-06  Essentials         Diary     120          UPI
# 4 2023-01-06  Essentials       Perfume    1500         Cash

# %%
plt.violinplot(df["Amount"], showmedians=True)
# Out:
# {'bodies': [<matplotlib.collections.FillBetweenPolyCollection at 0x2040a772680>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x2040a772c50>,
#  'cmins': <matplotlib.collections.LineCollection at 0x2040a12c7f0>,
#  'cbars': <matplotlib.collections.LineCollection at 0x2040a7737c0>,
#  'cmedians': <matplotlib.collections.LineCollection at 0x2040a773df0>}
