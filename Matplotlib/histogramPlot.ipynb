# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = [1,3,6,43,3,3,54,6,7,8,43,54,3,2,4,65,7,8,89,9,7,56,54,43,3,3,4,54,56,6,7,89,7,9,8,6,5,45,4,3,2,221,32,4,5,56,67,9,8]

plt.hist(data, bins=13, color="black")
plt.show()

# %%
data = pd.read_excel("expense3.xlsx")
df = pd.DataFrame(data)

data.head(5)
# Out:
#         Date    Category Sub-Category   Amount Payment Mode
# 0 2023-01-01     Grocery       Grocery      30         Cash
# 1 2023-01-02        Food    Restaurant     890          UPI
# 2 2023-01-04         123        Zomato     257          NaN
# 3 2023-01-06  Essentials         Diary     120          UPI
# 4 2023-01-06  Essentials       Perfume    1500         Cash

# %%
plt.hist(df["Amount"], bins=100, color="black")

plt.show()

# %%
grp = df.groupby("Category")["Amount"]

# %%
grp.indices
# Out:
# {123: array([2]),
#  'Bills': array([ 6, 26, 28]),
#  'Clothes': array([17, 18]),
#  'Essentials': array([ 3,  4,  9, 12, 15, 16, 25]),
#  'Food': array([ 1,  8, 11, 13, 20, 21, 23, 24]),
#  'Grocery': array([ 0,  5,  7, 10, 14, 19, 22, 27])}
