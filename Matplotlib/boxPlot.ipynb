# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
values = [8,9,4,1,5,4,58,8,9,6,7,12,26,25,14,20,11,2,1,5,4,58,8,9,6,7,12,26,25,14,20,11]

plt.boxplot(values)

plt.show()

# %%
values = [8,9,4,1,5,4,58,8,9,6,7,12,26,25,14,20,11,2,1,5,4,58,8,9,6,7,12,26,25,14,20,11]
l2 = [8,9,4,1,5,4,58,88,99,101,45,15]

val = [values, l2]

plt.boxplot(val)
plt.show()

# %%
data = pd.read_excel("expense3.xlsx")
data.head(5)
# Out:
#         Date    Category Sub-Category   Amount Payment Mode
# 0 2023-01-01     Grocery       Grocery      30         Cash
# 1 2023-01-02        Food    Restaurant     890          UPI
# 2 2023-01-04         123        Zomato     257          NaN
# 3 2023-01-06  Essentials         Diary     120          UPI
# 4 2023-01-06  Essentials       Perfume    1500         Cash

# %%
df = pd.DataFrame(data)
df.head()
# Out:
#         Date    Category Sub-Category   Amount Payment Mode
# 0 2023-01-01     Grocery       Grocery      30         Cash
# 1 2023-01-02        Food    Restaurant     890          UPI
# 2 2023-01-04         123        Zomato     257          NaN
# 3 2023-01-06  Essentials         Diary     120          UPI
# 4 2023-01-06  Essentials       Perfume    1500         Cash

# %%
plt.boxplot(df["Amount"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1c6c465bd30>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1c6c465b550>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1c6c465beb0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1c6c465b1f0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1c6c465aad0>],
#  'means': []}

# %%
plt.show()

# %%
grp = df.groupby("Payment Mode")["Amount"].sum()

# %%
grp
# Out:
# Payment Mode
# Card      780
# Cash     4637
# UPI     23305
# Name: Amount, dtype: int64

# %%
plt.boxplot(grp.values)
plt.show()

# %%
df.head()
# Out:
#         Date    Category Sub-Category   Amount Payment Mode
# 0 2023-01-01     Grocery       Grocery      30         Cash
# 1 2023-01-02        Food    Restaurant     890          UPI
# 2 2023-01-04         123        Zomato     257          NaN
# 3 2023-01-06  Essentials         Diary     120          UPI
# 4 2023-01-06  Essentials       Perfume    1500         Cash

# %%
grp = df.groupby("Category")["Amount"].sum()

# %%
grp
# Out:
# Category
# 123             257
# Bills         18724
# Clothes        2890
# Essentials     4485
# Food           2765
# Grocery        1028
# Name: Amount, dtype: int64

# %%
plt.boxplot(grp.values)
plt.show()
