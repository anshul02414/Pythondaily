# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import random

# %%
x = [4,7,8,9,4,5,6,4,5,6,4,5,7,4,5,21,1,2,1,5]

plt.stem(x)
plt.show()

# %%
a = np.random.randint(1,50,100)

plt.stem(a)
plt.show()

# %%
data = pd.read_excel("expense3.xlsx")

df = pd.DataFrame(data)

df.head(5)
# Out:
#         Date    Category Sub-Category   Amount Payment Mode
# 0 2023-01-01     Grocery       Grocery      30         Cash
# 1 2023-01-02        Food    Restaurant     890          UPI
# 2 2023-01-04         123        Zomato     257          NaN
# 3 2023-01-06  Essentials         Diary     120          UPI
# 4 2023-01-06  Essentials       Perfume    1500         Cash

# %%
plt.stem(df["Amount"])
# Out:
# <StemContainer object of 3 artists>

# %%
df["Amount"].unique()
# Out:
# array([   30,   890,   257,   120,  1500,   456, 16000,    70,    15,
#           50,   100,   780,   230,    26,  1000,  1890,    56,   530,
#           10,   140,   300,  1025,  1650,   150,  1074])

# %%
plt.stem(df["Amount"], orientation="horizontal")
# Out:
# <StemContainer object of 3 artists>

# %%
plt.stem(df["Amount"])
plt.plot(df["Amount"])

plt.show()
